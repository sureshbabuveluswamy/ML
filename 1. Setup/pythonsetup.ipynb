# %%
## to test python is working in your environment


# simple_sum.py
a = 5
b = 105
print("The sum of a and b is:", a + b)
# Out:
# The sum of a and b is: 110

# %%
#python version test
import sys

print("Python version")
print(sys.version)
print("Version info.")
print(sys.version_info)
# Out:
# Python version
# 3.9.6 (default, Oct 17 2025, 17:15:53)
# [Clang 17.0.0 (clang-1700.4.4.1)]
# Version info.
# sys.version_info(major=3, minor=9, micro=6, releaselevel='final', serial=0)

# %%
#to test if pandas is installed in your python environment

try:
    import pandas
    print("✅ Pandas is installed.")
    print("Version:", pandas.__version__)
except ImportError:
    print("❌ Pandas is NOT installed.")
# Out:
# ✅ Pandas is installed.
# Version: 2.3.3

# %%
# If pandas is not installed, you can install it using pip:
#
pip install pandas
pip install --upgrade pandas
# Out:
#   Cell In[8], line 3
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
#git config settings and ssh keygen
git config --global user.name "sureshbabuveluswamy"
git config --global user.email "sureshbabuveluswamy@gmail.com"

ssh-keygen -t rsa -b 4096 -C "sureshbabuveluswamy@gmail.com"

# %%
pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#to test if numpy is installed in your python environment
try:
    import numpy
    print("NumPy is installed, version:", numpy.__version__)
except ImportError:
    print("NumPy is NOT installed")
# Out:
# NumPy is installed, version: 2.0.2

# %%
pip list
# Out:
# Package            Version
# ------------------ -----------
# altgraph           0.17.2
# appnope            0.1.4
# asttokens          3.0.1
# comm               0.2.3
# debugpy            1.8.17
# decorator          5.2.1
# exceptiongroup     1.3.0
# executing          2.2.1
# future             0.18.2
# importlib_metadata 8.7.0
# ipykernel          6.31.0
# ipython            8.18.1
# jedi               0.19.2
# jupyter_client     8.6.3
# jupyter_core       5.8.1
# macholib           1.15.2
# matplotlib-inline  0.2.1
# nest-asyncio       1.6.0
# numpy              2.0.2
# packaging          25.0
# pandas             2.3.3
# parso              0.8.5
# pexpect            4.9.0
# pip                21.2.4
# platformdirs       4.4.0
# prompt_toolkit     3.0.52
# psutil             7.1.3
# ptyprocess         0.7.0
# pure_eval          0.2.3
# Pygments           2.19.2
# python-dateutil    2.9.0.post0
# pytz               2025.2
# pyzmq              27.1.0
# setuptools         58.0.4
# ...

# %%
#to test if matplotlib is installed in your python environment
try:
    import matplotlib
    print("Matplotlib is installed, version:", matplotlib.__version__)
except ImportError:
    print("Matplotlib is NOT installed")
# Out:
# Matplotlib is installed, version: 3.9.4

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.8 MB 7.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 45.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.7 MB 16.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 12.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 113 kB 26.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 44.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# upgrade pip to the latest version
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.8 MB 8.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    import sklearn
    print("scikit-learn is installed, version:", sklearn.__version__)
except ImportError:
    print("scikit-learn is NOT installed")
# Out:
# scikit-learn is installed, version: 1.6.1

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 17.7 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 49.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.
